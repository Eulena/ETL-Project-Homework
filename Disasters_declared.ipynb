# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy_utils import create_database, database_exists, drop_database

# %% [markdown]
# ## Extract CSVs into DataFrames

# %%
disaster_data = "../Resources/DisasterDeclarationsSummaries.csv"
disaster_data = pd.read_csv(disaster_data)
disaster_data.head()
# Out:
#    Declaration Number Individuals and Households Program  \
# 0                4419                                Yes
# 1                4418                                 No
# 2                4418                                 No
# 3                4418                                 No
# 4                4418                                 No
#
#   Individual Assistance Program Public Assistance Program  \
# 0                            No                       Yes
# 1                            No                       Yes
# 2                            No                       Yes
# 3                            No                       Yes
# 4                            No                       Yes
#
#   Hazard Mitigation Program State   Pres_Id Declaration Date Declaration Type  \
# 0                       Yes     AL       45         3/5/2019               DR
# 1                       Yes     WA       45         3/4/2019               DR
# 2                       Yes     WA       45         3/4/2019               DR
# 3                       Yes     WA       45         3/4/2019               DR
# 4                       Yes     WA       45         3/4/2019               DR
#
#      Disaster Type                                     Disaster Title  \
# 0          Tornado  SEVERE STORMS, STRAIGHT-LINE WINDS, AND TORNADOES
# 1  Severe Storm(s)  SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLO...
# 2  Severe Storm(s)  SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLO...
# 3  Severe Storm(s)  SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLO...
# 4  Severe Storm(s)  SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLO...
#
#    Start Date    End Date   Closed Date Place Code                 County  \
# 0    3/3/2019    3/3/2019  Undetermined      99081           Lee (County)
# 1  12/10/2018  12/24/2018  Undetermined      99009       Clallam (County)
# 2  12/10/2018  12/24/2018  Undetermined      99027  Grays Harbor (County)
# 3  12/10/2018  12/24/2018  Undetermined      99029        Island (County)
# 4  12/10/2018  12/24/2018  Undetermined      99031     Jefferson (County)
#
#    Declaration Request Number
# 0                       19006
# 1                       19005
# 2                       19005
# 3                       19005
# 4                       19005

# %%
presidents_data = "../Resources/Presidents.csv"
presidents_data = pd.read_csv(presidents_data)
presidents_data.head()
# Out:
#    Pres_Id          President  Term Start    Term End
# 0        1  George Washington  04/30/1789  03/04/1797
# 1        2         John Adams  03/04/1797  03/04/1801
# 2        3   Thomas Jefferson  03/04/1801  03/04/1809
# 3        4      James Madison  03/04/1809  03/04/1817
# 4        5       James Monroe  03/04/1817  03/04/1825

# %% [markdown]
# ## Transform DataFrame

# %%
# Merge dataframes then sort by Pres_Id
disasters_declared = disaster_data.merge(presidents_data, on="Pres_Id", how="left")
disasters_declared.head ()
# Out:
#    Declaration Number Individuals and Households Program  \
# 0                4419                                Yes
# 1                4418                                 No
# 2                4418                                 No
# 3                4418                                 No
# 4                4418                                 No
#
#   Individual Assistance Program Public Assistance Program  \
# 0                            No                       Yes
# 1                            No                       Yes
# 2                            No                       Yes
# 3                            No                       Yes
# 4                            No                       Yes
#
#   Hazard Mitigation Program State   Pres_Id Declaration Date Declaration Type  \
# 0                       Yes     AL       45         3/5/2019               DR
# 1                       Yes     WA       45         3/4/2019               DR
# 2                       Yes     WA       45         3/4/2019               DR
# 3                       Yes     WA       45         3/4/2019               DR
# 4                       Yes     WA       45         3/4/2019               DR
#
#      Disaster Type                                     Disaster Title  \
# 0          Tornado  SEVERE STORMS, STRAIGHT-LINE WINDS, AND TORNADOES
# 1  Severe Storm(s)  SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLO...
# 2  Severe Storm(s)  SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLO...
# 3  Severe Storm(s)  SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLO...
# 4  Severe Storm(s)  SEVERE WINTER STORMS, STRAIGHT-LINE WINDS, FLO...
#
#    Start Date    End Date   Closed Date Place Code                 County  \
# 0    3/3/2019    3/3/2019  Undetermined      99081           Lee (County)
# 1  12/10/2018  12/24/2018  Undetermined      99009       Clallam (County)
# 2  12/10/2018  12/24/2018  Undetermined      99027  Grays Harbor (County)
# 3  12/10/2018  12/24/2018  Undetermined      99029        Island (County)
# 4  12/10/2018  12/24/2018  Undetermined      99031     Jefferson (County)
#
#    Declaration Request Number     President Term Start  Term End
# 0                       19006  Donald Trump  1/20/2017  6/7/2019
# 1                       19005  Donald Trump  1/20/2017  6/7/2019
# 2                       19005  Donald Trump  1/20/2017  6/7/2019
# 3                       19005  Donald Trump  1/20/2017  6/7/2019
# 4                       19005  Donald Trump  1/20/2017  6/7/2019

# %%
# Sort data by Declaration Number
disasters_transformed=disasters_declared.sort_values("Declaration Number")
disasters_transformed.head()
# Out:
#        Declaration Number Individuals and Households Program  \
# 48554                   1                                 No
# 48553                   2                                 No
# 48552                   3                                 No
# 48551                   4                                 No
# 48550                   5                                 No
#
#       Individual Assistance Program Public Assistance Program  \
# 48554                           Yes                       Yes
# 48553                           Yes                       Yes
# 48552                           Yes                       Yes
# 48551                           Yes                       Yes
# 48550                           Yes                       Yes
#
#       Hazard Mitigation Program State   Pres_Id Declaration Date  \
# 48554                       Yes     GA       34         5/2/1953
# 48553                       Yes     TX       34        5/15/1953
# 48552                       Yes     LA       34        5/29/1953
# 48551                       Yes     MI       34         6/2/1953
# 48550                       Yes     MT       34         6/6/1953
#
#       Declaration Type Disaster Type            Disaster Title Start Date  \
# 48554               DR       Tornado                   TORNADO   5/2/1953
# 48553               DR       Tornado  TORNADO & HEAVY RAINFALL  5/15/1953
# 48552               DR         Flood                     FLOOD  5/29/1953
# 48551               DR       Tornado                   TORNADO   6/2/1953
# 48550               DR         Flood                    FLOODS   6/6/1953
#
#         End Date Closed Date    Place Code        County  \
# 48554   5/2/1953    6/1/1954  Undetermined  Undetermined
# 48553  5/15/1953    1/1/1958  Undetermined  Undetermined
# 48552  5/29/1953    2/1/1960  Undetermined  Undetermined
# 48551   6/2/1953    2/1/1956  Undetermined  Undetermined
# 48550   6/6/1953   12/1/1955  Undetermined  Undetermined
#
#        Declaration Request Number          President Term Start   Term End
# 48554                       53013  Dwight Eisenhower  1/20/1953  1/20/1961
# 48553                       53003  Dwight Eisenhower  1/20/1953  1/20/1961
# 48552                       53005  Dwight Eisenhower  1/20/1953  1/20/1961
# 48551                       53004  Dwight Eisenhower  1/20/1953  1/20/1961
# 48550                       53006  Dwight Eisenhower  1/20/1953  1/20/1961

# %%
disasters_transformed.columns
# Out:
# Index(['Declaration Number', 'Individuals and Households Program',
#        'Individual Assistance Program', 'Public Assistance Program',
#        'Hazard Mitigation Program', 'State ', 'Pres_Id', 'Declaration Date',
#        'Declaration Type', 'Disaster Type', 'Disaster Title', 'Start Date',
#        'End Date', 'Closed Date', 'Place Code', 'County',
#        'Declaration Request Number', 'President', 'Term Start', 'Term End'],
#       dtype='object')

# %%
#Rearrange columns in meaningful order 
disasters_finaltrans=disasters_transformed[['Pres_Id','President','State ','County','Declaration Date','Declaration Number','Declaration Type', 'Disaster Type', 'Disaster Title', 'Start Date',
       'End Date', 'Closed Date','Individuals and Households Program',
       'Individual Assistance Program', 'Public Assistance Program',
       'Hazard Mitigation Program']]
disasters_finaltrans.head()
# Out:
#        Pres_Id          President State         County Declaration Date  \
# 48554       34  Dwight Eisenhower     GA  Undetermined         5/2/1953
# 48553       34  Dwight Eisenhower     TX  Undetermined        5/15/1953
# 48552       34  Dwight Eisenhower     LA  Undetermined        5/29/1953
# 48551       34  Dwight Eisenhower     MI  Undetermined         6/2/1953
# 48550       34  Dwight Eisenhower     MT  Undetermined         6/6/1953
#
#        Declaration Number Declaration Type Disaster Type  \
# 48554                   1               DR       Tornado
# 48553                   2               DR       Tornado
# 48552                   3               DR         Flood
# 48551                   4               DR       Tornado
# 48550                   5               DR         Flood
#
#                  Disaster Title Start Date   End Date Closed Date  \
# 48554                   TORNADO   5/2/1953   5/2/1953    6/1/1954
# 48553  TORNADO & HEAVY RAINFALL  5/15/1953  5/15/1953    1/1/1958
# 48552                     FLOOD  5/29/1953  5/29/1953    2/1/1960
# 48551                   TORNADO   6/2/1953   6/2/1953    2/1/1956
# 48550                    FLOODS   6/6/1953   6/6/1953   12/1/1955
#
#       Individuals and Households Program Individual Assistance Program  \
# 48554                                 No                           Yes
# 48553                                 No                           Yes
# 48552                                 No                           Yes
# 48551                                 No                           Yes
# 48550                                 No                           Yes
#
#       Public Assistance Program Hazard Mitigation Program
# 48554                       Yes                       Yes
# 48553                       Yes                       Yes
# 48552                       Yes                       Yes
# 48551                       Yes                       Yes
# 48550                       Yes                       Yes

# %%
Disasters_byPres=disasters_finaltrans.groupby("President")["Declaration Date"].count().reset_index()

# Rename the column headers
Disasters_byPres=Disasters_byPres.rename(columns={"Declaration Date": "Count of Disasters Declared"})
Disasters_byPres
# Out:
#             President  Count of Disasters Declared
# 0        Barack Obama                        10250
# 1        Bill Clinton                         9697
# 2        Donald Trump                         2480
# 3   Dwight Eisenhower                          106
# 4         George Bush                         2083
# 5      George W. Bush                        15107
# 6         Gerald Ford                         1183
# 7        Jimmy Carter                         2261
# 8     John F. Kennedy                           52
# 9   Lyndon B. Johnson                         1046
# 10      Richard Nixon                         2783
# 11      Ronald Reagan                         1507

# %%
disasters_finaltrans.to_csv('C:\\Users\\monic\\Desktop\\ETL\\new_disasterfile.csv')

# %% [markdown]
# ## Create Database Connection

# %%
connection_string = "postgres:Raffy1768@localhost:5432/disasters_db"
engine = create_engine(f'postgresql://{connection_string}')
engine.table_names()
# Out:
# ['disasters']

# %%
connection = engine.connect()
Base = declarative_base()
Base.metadata.drop_all(engine)

# %%
# Confirm tables
engine.table_names()
# Out:
# ['disasters']

# %% [markdown]
# ## Load DataFrames into database

# %%
disasters_finaltrans.to_sql(name='disasters', con=engine, if_exists='append', index=True)
